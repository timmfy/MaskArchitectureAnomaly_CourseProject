# %%
# !python3 eomt/main.py fit \
  -c eomt/configs/dinov2/coco/panoptic/eomt_base_640_2x_finetuning.yaml \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --data.path datasets/cityscapes \
  --model.ckpt_path eomt/weights/eomt_coco.bin \
  --model.load_ckpt_class_head False
# Out:
# Seed set to 0
# INFO:root:Loaded 195 keys
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /Users/timon/.netrc.
# wandb: Currently logged in as: tkhudonogov (s349865-team-spritz) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 1cy1ae93 (0.2s)
# wandb: ⣽ setting up run 1cy1ae93 (0.2s)
# wandb: ⣾ setting up run 1cy1ae93 (0.2s)
# wandb: ⣷ setting up run 1cy1ae93 (0.2s)
# wandb: Tracking run with wandb version 0.26.0
# wandb: Run data is saved locally in wandb/run-20260430_150104-1cy1ae93
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run coco_panoptic_eomt_base_640
# wandb: ⭐️ View project at https://wandb.ai/s349865-team-spritz/eomt
# wandb: 🚀 View run at https://wandb.ai/s349865-team-spritz/eomt/runs/1cy1ae93
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# Loading `train_dataloader` to estimate number of stepping batches.
# /Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# /Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
#
#    | Name                     | Type                        | Params | Mode  | FLOPs
# ------------------------------------------------------------------------------------------
# 0  | network                  | EoMT                        | 93.6 M | train | 0
# 1  | network.encoder          | ViT                         | 86.9 M | train | 0
# 2  | network.encoder.backbone | VisionTransformer           | 86.9 M | train | 0
# 3  | network.q                | Embedding                   | 153 K  | train | 0
# 4  | network.class_head       | Linear                      | 15.4 K | train | 0
# 5  | network.mask_head        | Sequential                  | 1.8 M  | train | 0
# 6  | network.mask_head.0      | Linear                      | 590 K  | train | 0
# 7  | network.mask_head.1      | GELU                        | 0      | train | 0
# 8  | network.mask_head.2      | Linear                      | 590 K  | train | 0
# 9  | network.mask_head.3      | GELU                        | 0      | train | 0
# 10 | network.mask_head.4      | Linear                      | 590 K  | train | 0
# 11 | network.upscale          | Sequential                  | 4.7 M  | train | 0
# 12 | network.upscale.0        | ScaleBlock                  | 2.4 M  | train | 0
# 13 | network.upscale.1        | ScaleBlock                  | 2.4 M  | train | 0
# 14 | criterion                | MaskClassificationLoss      | 0      | train | 0
# 15 | criterion.matcher        | Mask2FormerHungarianMatcher | 0      | train | 0
# 16 | metrics                  | ModuleList                  | 0      | train | 0
# 17 | metrics.0                | MulticlassJaccardIndex      | 0      | train | 0
# 18 | metrics.1                | MulticlassJaccardIndex      | 0      | train | 0
# 19 | metrics.2                | MulticlassJaccardIndex      | 0      | train | 0
# 20 | metrics.3                | MulticlassJaccardIndex      | 0      | train | 0
# ------------------------------------------------------------------------------------------
# 93.6 M    Trainable params
# 0         Non-trainable params
# 93.6 M    Total params
# 374.302   Total estimated model params size (MB)
# 304       Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# 5lW0430 15:01:42.554000 75977 torch/_inductor/utils.py:1731] [13/0] Not enough SMs to use max_autotune_gemm mode
# Epoch 0/23 ━━━━━━━━━━━━━━━━━━━━━━━ 0/1487 0:00:10 • -:--:-- 0.00it/s v_num: ae93it/s
# Traceback (most recent call last):
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/eomt/main.py", line 183, in <module>
#     cli_main()
#     ~~~~~~~~^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/eomt/main.py", line 161, in cli_main
#     LightningCLI(
#     ~~~~~~~~~~~~^
#         LightningModule,
#         ^^^^^^^^^^^^^^^^
#     ...<15 lines>...
#         },
#         ^^
#     )
#     ^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/eomt/main.py", line 111, in __init__
#     super().__init__(*args, **kwargs)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/cli.py", line 421, in __init__
#     self._run_subcommand(self.subcommand)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/cli.py", line 759, in _run_subcommand
#     fn(**fn_kwargs)
#     ~~^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/eomt/main.py", line 157, in fit
#     self.trainer.fit(model, **kwargs)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py", line 584, in fit
#     call._call_and_handle_interrupt(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self,
#         ^^^^^
#     ...<6 lines>...
#         weights_only,
#         ^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py", line 49, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py", line 630, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py", line 1079, in _run
#     results = self._run_stage()
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/trainer.py", line 1123, in _run_stage
#     self.fit_loop.run()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py", line 217, in run
#     self.advance()
#     ~~~~~~~~~~~~^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py", line 465, in advance
#     self.epoch_loop.run(self._data_fetcher)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 153, in run
#     self.advance(data_fetcher)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/training_epoch_loop.py", line 352, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 192, in run
#     self._optimizer_step(batch_idx, closure)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 270, in _optimizer_step
#     call._call_lightning_module_hook(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         trainer,
#         ^^^^^^^^
#     ...<4 lines>...
#         train_step_and_backward_closure,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py", line 177, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/core/module.py", line 1368, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/core/optimizer.py", line 154, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/strategies/strategy.py", line 239, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/plugins/precision/amp.py", line 79, in optimizer_step
#     closure_result = closure()
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 146, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 140, in closure
#     self._backward_fn(step_output.closure_loss)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/loops/optimization/automatic.py", line 241, in backward_fn
#     call._call_strategy_hook(self.trainer, "backward", loss, optimizer)
#     ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/trainer/call.py", line 329, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/strategies/strategy.py", line 213, in backward
#     self.precision_plugin.backward(closure_loss, self.lightning_module, optimizer, *args, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/plugins/precision/precision.py", line 73, in backward
#     model.backward(tensor, *args, **kwargs)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/lightning/pytorch/core/module.py", line 1137, in backward
#     loss.backward(*args, **kwargs)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/torch/_tensor.py", line 631, in backward
#     torch.autograd.backward(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         self, gradient, retain_graph, create_graph, inputs=inputs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/torch/autograd/__init__.py", line 381, in backward
#     _engine_run_backward(
#     ~~~~~~~~~~~~~~~~~~~~^
#         tensors,
#         ^^^^^^^^
#     ...<5 lines>...
#         accumulate_grad=True,
#         ^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/timon/polito/ai/MaskArchitectureAnomaly_CourseProject/.venv/lib/python3.13/site-packages/torch/autograd/graph.py", line 869, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         t_outputs, *args, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )  # Calls into the C++ engine to run the backward pass
#     ^
# NotImplementedError: The operator 'aten::grid_sampler_2d_backward' is not currently implemented for the MPS device. If you want this op to be considered for addition please comment on https://github.com/pytorch/pytorch/issues/141287 and mention use-case, that resulted in missing op as well as commit hash 70d99e998b4955e0049d13a98d77ae1b14db1f45. As a temporary fix, you can set the environment variable `PYTORCH_ENABLE_MPS_FALLBACK=1` to use the CPU as a fallback for this op. WARNING: this will be slower than running natively on MPS.
# wandb:
# wandb: 🚀 View run coco_panoptic_eomt_base_640 at: https://wandb.ai/s349865-team-spritz/eomt/runs/1cy1ae93
